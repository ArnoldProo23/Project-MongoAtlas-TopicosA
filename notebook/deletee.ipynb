# %% [markdown]
# # Eliminar documentos

# %%
from connect import db

eliminar = db.libros

# Eliminar un documento
res = eliminar.delete_one({'titulo':'Cien años de soledad'})
print('Eliminados:', res.deleted_count)
# Out:
# Eliminados: 1
